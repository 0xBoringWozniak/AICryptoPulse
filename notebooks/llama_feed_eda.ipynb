# %%
import os

import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams.update({
    'font.size': 14,
    'font.family': 'serif',
    'axes.linewidth': 1.0,
    'axes.labelsize': 16,
    'lines.linewidth': 2,
    'lines.markersize': 7,
    'xtick.major.size': 5,
    'ytick.major.size': 5,
    'figure.figsize': (6,4),
    'legend.frameon': False
})
from sqlalchemy import create_engine

# %%
db_path = os.getenv("DB_URI")
assert db_path is not None and db_path != ""
engine = create_engine(db_path)

# %% [markdown]
# ## News Data

# %%
news = pd.read_sql('SELECT * FROM dl_feed_news', engine)

# %%
news.head()
# Out:
#                                                 guid  \
# 0                         QTCX3BSV4FGYVNQWN6GPR5BEQA
# 1                         KJRQ4VEHRZBATK2WKHKTORU4RQ
# 2  https://www.dlnews.com/articles/markets/bizarr...
# 3                         ZMIUV2NEEZAEVFEKMMEEX5KNGQ
# 4                         6T2OJZBRUBFANOVS2ATPLJHZJU
#
#                                                title  \
# 0  Tether CEO Ardoino Says He Expects U.S. Will C...
# 1  Aurum Launches $1B Tokenized Fund for Data Cen...
# 2  How bizarre AI cults are creating a new billio...
# 3  Bitcoin Exchange River Financial Allowing User...
# 4  Metaplanet Raises $66 Million Through Stocks A...
#
#                                              content  \
# 0  Tether CEO Paolo Ardoino told a U.S. crowd on ...
# 1  The vehicle will focus on data center investme...
# 2  Inside the obscure world of AI cult tokens and...
# 3  Not a bank itself, River has teamed up with Le...
# 4  MetaPlanet completes its 11th series of stock ...
#
#                                                 link  \
# 0  https://www.coindesk.com/policy/2024/10/22/tet...
# 1  https://www.coindesk.com/business/2024/10/22/a...
# 2  https://www.dlnews.com/articles/markets/bizarr...
# 3  https://www.coindesk.com/business/2024/10/22/b...
# 4  https://www.coindesk.com/business/2024/10/22/m...
#
#                    pub_date                      topic sentiment  \
# 0 2024-10-22 18:23:41+00:00  Regulation and Compliance  positive
# 1 2024-10-22 18:09:27+00:00      Tokenized Investments  positive
# 2 2024-10-22 17:55:00+00:00        Speculative Trading  negative
# 3 2024-10-22 16:43:10+00:00   Digital Finance Services  positive
# 4 2024-10-22 16:22:06+00:00      Investment Strategies  positive
#
#                                             entities  content_length  \
# 0  [Tether, Paolo Ardoino, U.S., DC Fintech Week,...             221
# 1  [Aurum, XRP Ledger, Zoniqx, United States, Uni...             196
# 2  [AI cults, memecoins, cryptocurrency, speculat...             114
# 3                 [River Financial, Lead Bank, FDIC]             143
# 4                             [MetaPlanet, Evo Fund]             159
#
#          date        source
# 0  2024-10-22  coindesk.com
# 1  2024-10-22  coindesk.com
# 2  2024-10-22    dlnews.com
# 3  2024-10-22  coindesk.com
# 4  2024-10-22  coindesk.com

# %%
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242 entries, 0 to 2241
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   guid       2242 non-null   object
#  1   title      2242 non-null   object
#  2   content    1511 non-null   object
#  3   link       2242 non-null   object
#  4   pub_date   2242 non-null   datetime64[ns, UTC]
#  5   topic      2242 non-null   object
#  6   sentiment  2242 non-null   object
#  7   entities   2242 non-null   object
# dtypes: datetime64[ns, UTC](1), object(7)
# memory usage: 140.2+ KB

# %%
news['content_length'] = news['content'].astype(str).apply(len)

plt.figure(figsize=(10, 6))
plt.hist(news['content_length'], bins=20)
plt.xlabel('Content Length')
plt.ylabel('Frequency')
plt.title('Histogram of Content Lengths')
plt.show()

# %%
news['date'] = news['pub_date'].dt.date

daily_news_count = news.groupby('date')['title'].count()

plt.figure(figsize=(12, 6))
plt.plot(daily_news_count.index, daily_news_count.values)
plt.xlabel('Date')
plt.ylabel('Number of News Articles')
plt.title('Daily News Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
news.groupby('date')['title'].count().mean()
# Out:
# 41.51851851851852

# %%
news['source'] = news['link'].str.extract(r'(?:https?://)?(?:www\.)?([^/]+)')
source_counts = news['source'].value_counts()
plt.figure(figsize=(10, 8))
plt.pie(source_counts, labels=source_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of News Sources')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Twitter Data

# %%
twitter = pd.read_sql('SELECT * FROM dl_feed_tweets', engine)

# %%
twitter.head()
# Out:
#               tweet_id                 tweet_created_at  \
# 0  1848796310335357145 2024-10-22 18:39:24.299000+00:00
# 1  1848794535507464461 2024-10-22 18:32:21.331000+00:00
# 2  1848791189853487472 2024-10-22 18:19:03.502000+00:00
# 3  1848788471671853253 2024-10-22 18:08:15.437000+00:00
# 4  1848779677759918511 2024-10-22 17:33:18.793000+00:00
#
#                                                tweet  \
# 0  Notcoin founder says Binance and ‘poor guys fr...
# 1  A fresh wallet withdrew 1.06M $PENDLE($5.08M) ...
# 2  Rep. French Hill remains hopeful for crypto le...
# 3  Bitcoin mining difficulty hits new all-time hi...
# 4  Tether is 'doubling down' on communication and...
#
#                                                  url    user_name  \
# 0  https://twitter.com/TheBlock__/status/18487963...    The Block
# 1  https://twitter.com/lookonchain/status/1848794...  Lookonchain
# 2  https://twitter.com/TheBlock__/status/18487911...    The Block
# 3  https://twitter.com/TheBlock__/status/18487884...    The Block
# 4  https://twitter.com/TheBlock__/status/18487796...    The Block
#
#    user_handle sentiment
# 0   TheBlock__  negative
# 1  lookonchain   neutral
# 2   TheBlock__  positive
# 3   TheBlock__  positive
# 4   TheBlock__  positive

# %%
twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tweet_id          1250 non-null   object
#  1   tweet_created_at  1250 non-null   datetime64[ns, UTC]
#  2   tweet             1250 non-null   object
#  3   url               1250 non-null   object
#  4   user_name         1250 non-null   object
#  5   user_handle       1250 non-null   object
#  6   sentiment         1190 non-null   object
# dtypes: datetime64[ns, UTC](1), object(6)
# memory usage: 68.5+ KB

# %%
twitter['content_length'] = twitter['tweet'].astype(str).apply(len)
plt.figure(figsize=(10, 6))
plt.hist(twitter['content_length'])
plt.xlabel('Content Length')
plt.ylabel('Frequency')
plt.title('Histogram of Content Lengths')
plt.show()

# %%
twitter['date'] = twitter['tweet_created_at'].dt.date

daily_tweets_count = twitter.groupby('date')['tweet'].count()

plt.figure(figsize=(12, 6))
plt.plot(daily_tweets_count.index, daily_tweets_count.values)
plt.xlabel('Date')
plt.ylabel('Number of Tweets')
plt.title('Daily Tweets Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
twitter.groupby('date')['tweet'].count().mean()
# Out:
# 23.58490566037736

# %%
source_counts = twitter['source'].value_counts()
threshold = 0.02 * source_counts.sum()
filtered_counts = source_counts[source_counts >= threshold]
others_sum = source_counts[source_counts < threshold].sum()
filtered_counts['Others'] = others_sum

plt.figure(figsize=(10, 8))
plt.pie(filtered_counts, labels=filtered_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Tweet Sources (Grouped)')
plt.axis('equal')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128737 (\N{SHIELD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128310 (\N{LARGE ORANGE DIAMOND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
twitter['source'].unique()
# Out:
# array(['The Block', 'Lookonchain', 'Lido', 'Coinbase 🛡️', 'Binance',
#        'Coinbase International Exchange 🛡️', 'Coinbase Assets 🛡️',
#        'Robinhood Crypto EU', 'vitalik.eth', 'Donald J. Trump',
#        'The Block Pro Headlines', 'Blockworks', 'db', 'ZachXBT',
#        'CZ 🔶 BNB', 'The Block (Meet Us at Emergence)', 'GCR', 'zoomer',
#        'PeckShield Inc.', 'WBTC', 'Cobie',
#        'The Block (Come to Emergence)', 'Rocket Pool', 'Sam Altman'],
#       dtype=object)

# %%
len(twitter['source'].unique())
# Out:
# 24
